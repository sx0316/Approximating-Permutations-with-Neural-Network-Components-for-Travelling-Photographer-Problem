# %%
num_states=9
num_obs=6
num_eff_states = 4
f = [[0 for i in range(num_obs)] for j in range(num_states)]
g = [[0 for i in range(num_obs)] for j in range(num_states)]
m = [0 for j in range(num_states)]
m4 = [0 for j in range(num_eff_states)]

f[0][0] = lambda a : '2,' if a > 0.575 else ''
f[0][1] = lambda a : '5,' if a > 0.731 else ''
f[0][2] = lambda a : '7,' if a > 0.097 else ''
f[0][3] = lambda a : '8,' if a > 0.978 else ''
f[0][4] = lambda a : '9,' if a > 0.015 else ''
f[0][5] = lambda a : '12,' if a > 0.535 else ''

f[1][1] = lambda a : '5,' if a > 0.324 else ''
f[1][2] = lambda a : '10,' if a > 0.812 else ''
f[1][3]= lambda a : '11,' if a > 0.212 else ''
f[1][4] = lambda a : '0,' if a > 0.809 else ''
f[1][5]= lambda a : '16,' if a > 0.719 else ''
f[1][0]= lambda a : '6,' if a > 0.719 else ''
 
f[2][0] = lambda a :  '3,' if a > 0.317 else ''
f[2][1] = lambda a :  '5,' if a > 0.434 else ''
f[2][2] = lambda a :  '9,' if a > 0.986 else ''
f[2][3] = lambda a :  '13,' if a > 0.294 else ''
f[2][4] = lambda a : '7,' if a > 0.16 else ''
f[2][5] = lambda a :  '13,' if a > 0.312 else ''

f[3][0] = lambda a : '0,' if  a > 0.480 else ''
f[3][1] = lambda a :  '2,' if a > 0.257 else ''
f[3][2] = lambda a :  '4,' if a > 0.642 else ''
f[3][3] = lambda a :  '7,' if a > 0.176 else ''
f[3][4] = lambda a :  '10,' if a > 0.923 else ''
f[3][5] = lambda a :  '13,' if a > 0.549 else ''

f[4][0] = lambda a :  '1,' if a > 0.412 else ''
f[4][1] = lambda a :  '5,' if a > 0.166 else ''
f[4][2] = lambda a :  '8,' if a > 0.76 else ''
f[4][3] = lambda a :  '17,' if a > 0.286 else ''
f[4][4] = lambda a :  '14,' if a > 0.427 else ''
f[4][5] = lambda a :  '13,' if a > 0.62 else ''

f[5][0] = lambda a : '12,' if  a > 0.480 else ''
f[5][1] = lambda a :  '15,' if a > 0.257 else ''
f[5][2] = lambda a :  '18,' if a > 0.286 else ''
f[5][3] = lambda a :  '1,' if a > 0.427 else ''
f[5][4] = lambda a :  '2,' if a > 0.62 else ''
f[5][5] = lambda a :  '3,' if a > 0.549 else ''

f[6][0] = lambda a :  '10,' if a > 0.9 else ''
f[6][1] = lambda a :  '15,' if a > 0.86 else ''
f[6][2] = lambda a :  '3,' if a > 0.4 else ''
f[6][3] = lambda a :  '7,' if a > 0.1 else ''
f[6][4] = lambda a :  '1,' if a > 0.427 else ''
f[6][5] = lambda a :  '9,' if a > 0.3 else ''

f[7][0] = lambda a : '18,' if  a > 0.404 else ''
f[7][1] = lambda a :  '3,' if a > 0.896 else ''
f[7][2] = lambda a :  '12,' if a > 0.138 else ''
f[7][3] = lambda a :  '10,' if a > 0.452 else ''
f[7][4] = lambda a :  '18,' if a > 0.627 else ''
f[7][5] = lambda a :  '9,' if a > 0.235 else ''

f[8][0] = lambda a :  '2,' if a > 0.879 else ''
f[8][1] = lambda a :  '10,' if a > 0.387 else ''
f[8][2] = lambda a :  '16,' if a > 0.614 else ''
f[8][3] = lambda a :  '17,' if a > 0.75 else ''
f[8][4] = lambda a :  '8,' if a > 0.759 else ''
f[8][5] = lambda a :  '11,' if a > 0.231 else ''

g[0][0] = lambda a : 0.425 if a =='2' else False
g[0][1] = lambda a : 0.269 if a =='5' else False
g[0][2] = lambda a : 0.903 if a == '7' else False
g[0][3] = lambda a : 0.022 if a == '8' else False
g[0][4] = lambda a : 0.985 if a == '9'else False
g[0][5] = lambda a : 0.465 if a == '12'else False

g[1][0] = lambda a : 0.188 if a == '10' else False
g[1][1]= lambda a : 0.788 if a  == '11' else False
g[1][2] = lambda a : 0.191 if a == '0' else False
g[1][3]= lambda a : 0.281 if a == '16' else False
g[1][4]= lambda a : 0.281 if a == '6' else False
g[1][5]= lambda a : 0.676 if a == '5' else False

g[2][0] = lambda a :  0.683 if a == '3' else False
g[2][1] = lambda a :  0.566 if a == '5' else False
g[2][2] = lambda a :  0.024 if a == '6' else False
g[2][3] = lambda a : 0.7 if a  == '13' else False
g[2][4] = lambda a : 0.84 if a == '7' else False
g[2][5] = lambda a :  0.688 if a == '13' else False

g[3][0] = lambda a : 0.52 if  a == '0'else False
g[3][1] = lambda a :  0.743 if a == '2'else False
g[3][2] = lambda a :  0.358 if a == '4'else False
g[3][3] = lambda a :  0.824 if a == '7'else False
g[3][4] = lambda a :  0.077 if a == '10'else False
g[3][5] = lambda a :  0.451 if a == '13'else False

g[4][0] = lambda a :  0.588 if a == '1' else False
g[4][1] = lambda a :  0.834 if a == '5'else False
g[4][2] = lambda a :  0.24 if a == '8'else False
g[4][3] = lambda a :  0.714 if a == '17'else False
g[4][4] = lambda a :  0.573 if a == '14'else False
g[4][5] = lambda a :  0.38 if a =='13'else False

g[5][0] = lambda a : 0.52 if  a == '12' else False
g[5][1] = lambda a : 0.75 if a == '15' else False
g[5][2] = lambda a : 0.72 if a ==  '18' else False
g[5][3] = lambda a : 0.58 if a ==  '1' else False
g[5][4] = lambda a :  0.38 if a == '2' else False
g[5][5] = lambda a :  0.45 if a == '3' else False

g[6][0] = lambda a :  0.1 if a  == '10' else False
g[6][1] = lambda a :  0.14 if a ==  '15' else False
g[6][2] = lambda a :  0.6 if a  ==  '3' else False
g[6][3] = lambda a :  0.9 if a  == '7' else False
g[6][4] = lambda a :  0.58 if a ==  '11' else False
g[6][5] = lambda a :  0.7 if a == '9' else False

g[7][0] = lambda a : 0.396 if  a == '18 ' else False
g[7][1] = lambda a : 0.104  if a == "3" else False
g[7][2] = lambda a : 0.862  if a == "12" else False
g[7][3] = lambda a : 0.548  if a  == "10" else False
g[7][4] = lambda a : 0.373  if a  == "18" else False
g[7][5] = lambda a : 0.765  if a  == "9" else False

g[8][0] = lambda a :  0.121  if a == "2" else False
g[8][1] = lambda a :  0.613  if a == "10" else False
g[8][2] = lambda a :  0.386 if a == "16" else False
g[8][3] = lambda a :  0.25 if a == "17" else False
g[8][4] = lambda a :  0.241 if a == "8" else False
g[8][5] = lambda a :  0.769 if a == "11" else False

m[0] = lambda a :  [0, 0.2, 0.15, 0.1, 0.15, 0.1, 0.1, 0.1, 0.1]
m[1] = lambda a :  [0.05, 0, 0.20, 0.1, 0.1, 0.15, 0.15, 0.15, 0.1]
m[2] = lambda a : [0.1, 0.15, 0, 0.05, 0.1, 0.2, 0.1, 0.2, 0.1]
m[3] = lambda a : [0.3, 0.15, 0.05, 0, 0.1, 0.2, 0.05, 0.1, 0.05]
m[4] = lambda a : [0.2, 0.1, 0.15, 0.17, 0, 0.15, 0.1, 0.1, 0.03]
m[5] = lambda a : [0.2, 0.15, 0.1, 0.1, 0.2, 0 , 0.1, 0.1, 0.05]
m[6] = lambda a : [0.2, 0.1, 0.1, 0.2, 0.1, 0.05, 0, 0.1, 0.15]
m[7] = lambda a : [0.2, 0, 0, 0.1, 0.2, 0 , 0, 0, 0.5]
m[8] = lambda a : [0.2, 0, 0.1, 0.2, 0.1, 0.05, 0, 0.35, 0]

m4[0] = lambda a :  [0, 0.45, 0.35, 0.2 ]
m4[1] = lambda a :  [0.25, 0, 0.35, 0.40]
m4[2] = lambda a : [0.4, 0.35, 0, 0.25]
m4[3] = lambda a : [0.3, 0.55, 0.15, 0]
print(2)

import numpy as np
import random
# Out:
# 2

# %%
def find_states_connected(obs):
    available_states = []
    for i in range(num_states):
        x = fnnn(i, obs)
        if x:
            available_states.append(i)

    return available_states

def fnnn(state, n):
    for i in range(num_obs):
    
        fnn = g[state][i]
       # print('sd', state, i, n, g[state][i])
        res = fnn(n)
        xs = []
        for i in range(3):
            xs.append(random.uniform(0, res))
        x = max(xs)
        if res:
            return x

# %%
def normalize(v):
    sum_ = 0
    for item in v:
        sum_ += item
    res = []
    if sum_ == 0:
       # print("error in normalize")
        return -1
    
    for item in v:
        res.append(item/sum_)
    return res

# %%
s = [0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2,0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2, 0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2,0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2]
p = s*2
print(p)
# Out:
# [0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2, 0, 0, 1, 2, 4, 2, 1, 2, 1, 0, 1, 4, 0, 1, 3, 1, 2, 2, 4, 2]

# %%
start_state = [0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2,0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2, 0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2,0,0,1,2,4,2,1,2,1,0,1,4,0,1,3,1,2,2,4,2]
start_state2 = start_state*2
num_trails, num_transitions = 100,6
file = open("new9_.txt", "a")

state_trails, obs_seq, char_trails = [], [], []
off = ord('a')
for i in range(num_trails):
    state = start_state[i%80] 
    visited,visited2,visited3 = [], [], []
    path, obs = '',  ''
    ss = ''
    try:
        for ii in range(num_transitions):
            obs_indices = [np.random.randint(num_obs) for i in range(15)]
            cur_obs = []
            for ind in obs_indices:
                fn = f[state][ind]
                seed = np.random.rand()
                y = fn(seed)

                if y not in cur_obs and y:
                    cur_obs.append(int(y[:-1]))
            related_states = [0 for i in range(num_states)]
            cur_obs = sorted(list(set(cur_obs)))
            for yy in cur_obs:
                obs = obs + str(yy) + ','
                more_correlated_states = find_states_connected(str(yy))
                for s in more_correlated_states:
                    related_states[s] += 1


          #  print("cur:",cur_obs)
            obs = obs[:-1] + ';' #+ '; '
            path = path + str(state) +' '
            fn = m[state](0) 
            for v in visited:
                fn[v] = 0

            trans = normalize(fn)
            cur_state = state
           # print(weighted_trans, related_states, fn(0), state)
            visited.append(state)
            visited2.append(state)
            visited3.append(chr(off + state))
            for _ in range(len(cur_obs)):
                ss = ss + str(cur_state) + ' '# + '.' + str(_) + ' '

            x = np.random.sample(np.arange(0, num_states), p = trans)
            state = x
    except Exception as e:
        state_trails.append(visited)
        obs_seq.append(obs[:-1])
        char_trails.append(visited3)
    
        
   # state_trails.append(visited)
    state_trails.append(visited)
    obs_seq.append(obs[:-1])
    char_trails.append(visited3)
    
   # print(i+1, visited, obs[:-1], ss)
    visited_str = ''
    for state_s in visited2:
        visited_str = visited_str + ' ' + str(state_s)
    #visited_str = visited_str #+ " | "
    print(visited, visited_str)
    file.write(obs + "| " + visited_str + "\n")
#print(state_trails, obs_seq)
# Out:
# [0, 4, 5, 1, 2, 7]  0 4 5 1 2 7
# [0, 4, 3, 5, 1, 6]  0 4 3 5 1 6
# [1, 8, 7, 0, 6, 3]  1 8 7 0 6 3
# [2, 6, 3, 0, 8, 7]  2 6 3 0 8 7
# [4, 7, 8, 2, 0, 1]  4 7 8 2 0 1
# [2, 8, 5, 0, 3, 7]  2 8 5 0 3 7
# [1, 4, 2, 3, 7, 8]  1 4 2 3 7 8
# [2, 1, 4, 7, 3, 0]  2 1 4 7 3 0
# [1, 7, 8, 0, 6, 2]  1 7 8 0 6 2
# [0, 6, 3, 5, 1, 4]  0 6 3 5 1 4
# [1, 2, 7, 4, 5, 0]  1 2 7 4 5 0
# [4, 7, 8, 0, 1, 5]  4 7 8 0 1 5
# [0, 6, 3, 5, 1, 7]  0 6 3 5 1 7
# [1, 3, 4, 6, 7, 8]  1 3 4 6 7 8
# [3, 0, 2, 6, 1, 5]  3 0 2 6 1 5
# [1, 3, 4, 0, 5, 6]  1 3 4 0 5 6
# [2, 8, 7, 0, 1, 4]  2 8 7 0 1 4
# [2, 5, 6, 0, 1, 8]  2 5 6 0 1 8
# [4, 8, 7, 3, 2, 6]  4 8 7 3 2 6
# [2, 1, 6, 0, 5, 4]  2 1 6 0 5 4
# [0, 8, 7, 3, 1, 6]  0 8 7 3 1 6
# [0, 4, 5, 6, 8, 7]  0 4 5 6 8 7
# [1, 6, 0, 7, 3, 5]  1 6 0 7 3 5
# [2, 7, 0, 8, 5, 6]  2 7 0 8 5 6
# [4, 6, 8, 0, 7, 3]  4 6 8 0 7 3
# [2, 4, 0, 3, 7, 8]  2 4 0 3 7 8
# [1, 4, 8, 7, 3, 0]  1 4 8 7 3 0
# [2, 3, 0, 1, 8, 7]  2 3 0 1 8 7
# [1, 5, 7, 4, 3, 0]  1 5 7 4 3 0
# ...

# %%
file.close()
print(state_trails[:50])
print(obs_seq[:50])
# Out:
# [[0, 4, 5, 1, 2, 7], [0, 4, 3, 5, 1, 6], [1, 8, 7, 0, 6, 3], [2, 6, 3, 0, 8, 7], [4, 7, 8, 2, 0, 1], [2, 8, 5, 0, 3, 7], [1, 4, 2, 3, 7, 8], [2, 1, 4, 7, 3, 0], [1, 7, 8, 0, 6, 2], [0, 6, 3, 5, 1, 4], [1, 2, 7, 4, 5, 0], [4, 7, 8, 0, 1, 5], [0, 6, 3, 5, 1, 7], [1, 3, 4, 6, 7, 8], [3, 0, 2, 6, 1, 5], [1, 3, 4, 0, 5, 6], [2, 8, 7, 0, 1, 4], [2, 5, 6, 0, 1, 8], [4, 8, 7, 3, 2, 6], [2, 1, 6, 0, 5, 4], [0, 8, 7, 3, 1, 6], [0, 4, 5, 6, 8, 7], [1, 6, 0, 7, 3, 5], [2, 7, 0, 8, 5, 6], [4, 6, 8, 0, 7, 3], [2, 4, 0, 3, 7, 8], [1, 4, 8, 7, 3, 0], [2, 3, 0, 1, 8, 7], [1, 5, 7, 4, 3, 0], [0, 3, 5, 6, 8, 4], [1, 3, 5, 7, 8, 4], [4, 2, 8, 7, 0, 1], [0, 1, 4, 3, 7, 8], [1, 8, 0, 6, 3, 4], [3, 0, 4, 2, 6, 8], [1, 5, 2, 6, 0, 7], [2, 5, 4, 6, 1, 0], [2, 5, 1, 7, 8, 0], [4, 5, 0, 1, 2, 7], [2, 5, 1, 7, 8, 3], [0, 1, 6, 4, 7, 8], [0, 2, 7, 3, 4, 6], [1, 7, 8, 2, 0, 4], [2, 6, 0, 8, 7, 4], [4, 6, 0, 8, 3, 2], [2, 0, 7, 8, 5, 3], [1, 5, 3, 0, 4, 6], [2, 5, 4, 1, 6, 8], [1, 7, 0, 8, 3, 5], [0, 7, 4, 2, 5, 6
# ...

# %%
file.close()
